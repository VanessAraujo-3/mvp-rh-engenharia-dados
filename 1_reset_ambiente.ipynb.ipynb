# %% [markdown]
# MVP Pipeline de Dados – Recursos Humanos
# Análise de Retenção e Eficiência Organizacional
#
# Vanessa Araújo
#
# PUC-RJ – MBA em Ciência de Dados e Analytics
# Disciplina de Engenharia de Dados
#
# Script para exclusão de todas as bases de dados do pipeline.

# %%
# Limpeza das tabelas (caso existam)
# %sql
DROP TABLE IF EXISTS bronze.hr_raw;
DROP TABLE IF EXISTS silver.employees;
DROP TABLE IF EXISTS silver.departments;
DROP TABLE IF EXISTS silver.managers;
DROP TABLE IF EXISTS silver.performance;
DROP TABLE IF EXISTS gold.turnover_metrics;
DROP TABLE IF EXISTS gold.absence_metrics;
DROP TABLE IF EXISTS gold.diversity_metrics;

DROP DATABASE IF EXISTS bronze CASCADE;
DROP DATABASE IF EXISTS silver CASCADE;
DROP DATABASE IF EXISTS gold CASCADE;
# Out:
#   File <command-4508884992884150>, line 3
#     DROP TABLE IF EXISTS bronze.hr_raw;
#          ^
# SyntaxError: invalid syntax

# %%
# Limpeza dos diretórios físicos no DBFS
dbutils.fs.rm("dbfs:/user/hive/warehouse/bronze.db", recurse=True)
dbutils.fs.rm("dbfs:/user/hive/warehouse/silver.db", recurse=True)
dbutils.fs.rm("dbfs:/user/hive/warehouse/gold.db", recurse=True)
# Out:
# ---------------------------------------------------------------------------
# ExecutionError                            Traceback (most recent call last)
# File <command-4508884992884151>, line 2
#       1 # Limpeza dos diretórios físicos no DBFS
# ----> 2 dbutils.fs.rm("dbfs:/user/hive/warehouse/bronze.db", recurse=True)
#       3 dbutils.fs.rm("dbfs:/user/hive/warehouse/silver.db", recurse=True)
#       4 dbutils.fs.rm("dbfs:/user/hive/warehouse/gold.db", recurse=True)
#
# File /databricks/python_shell/lib/dbruntime/remotefshandler/RemoteFsHandler.py:54, in prettify_exception_message.<locals>.f_with_exception_handling(*args, **kwargs)
#      51 class ExecutionError(Exception):
#      52     pass
# ---> 54 raise ExecutionError(str(e)) from None
#
# ExecutionError: Public DBFS root is disabled. Access is denied on path: /user/hive/warehouse/bronze.db
#
# JVM stacktrace:
# java.lang.UnsupportedOperationException
# ...
